# %% [markdown]
# ### Module 3: Conveyor Simulation (FIFO)
#
# This notebook executes the canonical script `simulation_just_FIFO.py`.

# %%
import os, sys
import runpy

# Execute the FIFO simulation pipeline
runpy.run_path('simulation_just_FIFO.py')
# Out:
# Loaded 11 orders, 11 totes
# Completed 0/11 orders
# Total time: 0.0,  Avg order time: 0.0000
# Flawed run: True
# FIFO results written:
#   c:\Users\Kikicat\Repos\MSE433-Case3-Conveyor-Simulation\Data\comparison/simulation_just_FIFO_summary.csv
#   c:\Users\Kikicat\Repos\MSE433-Case3-Conveyor-Simulation\Data\comparison/simulation_just_FIFO_order_times.csv
#   c:\Users\Kikicat\Repos\MSE433-Case3-Conveyor-Simulation\Data\comparison/simulation_just_FIFO_order_conveyor.csv
# {'__name__': '<run_path>',
#  '__doc__': None,
#  '__package__': '',
#  '__loader__': None,
#  '__spec__': None,
#  '__file__': 'simulation_just_FIFO.py',
#  '__cached__': None,
#  '__builtins__': {'__name__': 'builtins',
# ...
